# %%
print('a', 'b', sep='-')
# Out:
# a-b

# %%
print('Hi', end=' ')
print('World')
# Out:
# Hi World

# %%
print('Hi', end='-')
print('World')
# Out:
# Hi-World
# World

# %% [markdown]
# # f-strings

# %%
print(f'이름: 홍길동, 나이: 28')
# Out:
# 이름: 홍길동, 나이: 28

# %%
name = '홍길동'
나이 = 28
print(f'이름: {name}, 나이: {나이}')
# Out:
# 이름: 홍길동, 나이: 28

# %% [markdown]
# # 소수점 형식

# %%
pi = 3.14123123123
print(f'파이: {pi:.2f}')
# Out:
# 파이: 3.14

# %% [markdown]
# # 특수 문자와 이스케이프 시퀀스

# %%
print('첫 번째 줄\n두 번째 줄')
# Out:
# 첫 번째 줄
# 두 번째 줄

# %%
print('첫번째\t두번째')
# Out:
# 첫번째	두번째
